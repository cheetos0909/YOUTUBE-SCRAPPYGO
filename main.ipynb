# %% [markdown]
# ## SCRAPY GO:

# %%
from main import program
from main import omega

# %%
program()
# Out:
#               Author_Name                                            Comment  \
# 0   KaranamVenkat Poojith                         Wah man it’s good actually
# 1               Mauryajee           Bsdk.. Abe ye copy hai 59 ka Divine on 🔥
# 2              AKSHIT DEV                         Bhai flow ek dam hard hai❤
# 3                   stack                  mf put sagar shah in the video xD
# 4             BHASKAR DAS       Sagar Shah bhi hain is legendary video mein!
# ..                    ...                                                ...
# 95             BEAST-king  @samay bhai divine ne tera beat or title bhi c...
# 96     {SW} Sneak Warrior  <a href="https://www.youtube.com/watch?v=M-ZUQ...
# 97                   ZAID  Kr$na kills Rapper &amp; Samay Kills Masterpie...
# 98           Vikram Singh  Divine ne copy kiya h ye song divine ko police...
# 99     manoj salunke live            Did Sagar shah featured in this video?😂
#
# ...
